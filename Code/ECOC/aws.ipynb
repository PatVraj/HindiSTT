# %% [markdown]
# ## AWS S3 Audio Upload

# %%
import boto3
import os
import pandas as pd
from pydub import AudioSegment

# Initialize a session using Amazon S3
s3 = boto3.client('s3')

# Your bucket name
bucket_name = 'ecocaudio'

# Local directory containing the audio files
local_directory = '/Users/vrajpatel/Desktop/work/IBS/Komal_Kaur/HindiSTT/Code/ECOC/ElectionConduct_Audio'

# Path to the video_info.xlsx file
excel_file_path = '/Users/vrajpatel/Desktop/work/IBS/Komal_Kaur/HindiSTT/Code/ECOC/video_info.xlsx'

def list_s3_files(bucket_name):
    """List all files in the S3 bucket."""
    response = s3.list_objects_v2(Bucket=bucket_name)
    if 'Contents' in response:
        return [item['Key'] for item in response['Contents']]
    else:
        return []

def list_local_files(directory):
    """List all files in the local directory."""
    return [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]

def strip_extension(file_name):
    """Remove common extensions from file name for comparison."""
    return file_name.rsplit('.', 1)[0].rsplit('_16000hz', 1)[0]

def convert_to_16000hz(file_path):
    """Convert the audio file to 16000 Hz if it is not already in that format."""
    audio = AudioSegment.from_file(file_path)
    if audio.frame_rate != 16000:
        audio = audio.set_frame_rate(16000)
        audio.export(file_path, format="wav")
        print(f'Converted {file_path} to 16000 Hz')
    else:
        print(f'{file_path} is already in 16000 Hz')

def upload_new_files(local_directory, bucket_name, df):
    """Upload files to S3 that are not already in the bucket and update the Excel file."""
    s3_files = list_s3_files(bucket_name)
    local_files = list_local_files(local_directory)

    for file_name in local_files:
        stripped_name = strip_extension(file_name)
        if file_name not in s3_files:
            file_path = os.path.join(local_directory, file_name)
            try:
                # Convert the file to 16000 Hz if necessary
                convert_to_16000hz(file_path)
                
                # Upload the file to S3
                s3.upload_file(file_path, bucket_name, file_name)
                print(f'Successfully uploaded {file_name}')
                
                # Update the Excel file: set 'Uploaded' to TRUE for the uploaded file
                df.loc[df['Title'].apply(strip_extension) == stripped_name, 'Uploaded'] = True

            except Exception as e:
                print(f'Error uploading {file_name}: {e}')

# Load the Excel file
df = pd.read_excel(excel_file_path)

# Ensure the 'Uploaded' column exists in the DataFrame
if 'Uploaded' not in df.columns:
    df['Uploaded'] = False

# Upload new files and update the DataFrame
upload_new_files(local_directory, bucket_name, df)

# Save the updated DataFrame back to the Excel file
df.to_excel(excel_file_path, index=False)

print(f"Uploaded files have been marked in {excel_file_path}")

# %%
import json
import pandas as pd
import boto3
from io import BytesIO
from fuzzywuzzy import fuzz

# AWS S3 configuration
s3_bucket_name = 'ecocaudio'
s3_prefix = 'transcriptions/'  # If your files are in a specific folder

# Path to your Excel file (local)
excel_file = 'video_info.xlsx'

# Initialize S3 client
s3 = boto3.client('s3')

# Read the Excel file
df = pd.read_excel(excel_file)

# Function to clean filename
def clean_filename(filename):
    prefixes = ['transcribe_16HzAudio_LIVE__', 'transcribe_16HzAudio_LIVE___']
    suffixes = ['.json']
    
    for prefix in prefixes:
        if filename.startswith(prefix):
            filename = filename[len(prefix):]
    
    for suffix in suffixes:
        if filename.endswith(suffix):
            filename = filename[:-len(suffix)]
    
    filename = filename.replace('_', ' ')
    return filename.lower()

# Create a dictionary to store filename: (transcript, original_filename) pairs
transcripts = {}

# List objects in the S3 bucket
paginator = s3.get_paginator('list_objects_v2')
for page in paginator.paginate(Bucket=s3_bucket_name, Prefix=s3_prefix):
    for obj in page.get('Contents', []):
        if obj['Key'].endswith('.json'):
            # Get the JSON file content
            response = s3.get_object(Bucket=s3_bucket_name, Key=obj['Key'])
            file_content = response['Body'].read().decode('utf-8')
            data = json.loads(file_content)
            
            transcript = data['results']['transcripts'][0]['transcript']
            original_filename = obj['Key'].split('/')[-1]
            cleaned_filename = clean_filename(original_filename)
            transcripts[cleaned_filename] = (transcript, original_filename)

# Function to find best match and return transcript and matched filename
def get_transcript_and_filename(row):
    title = row['Title'].lower()
    best_match = max(transcripts.keys(), key=lambda x: fuzz.ratio(x, title))
    if fuzz.ratio(best_match, title) > 70:  # You can adjust this threshold
        return transcripts[best_match]
    return '', ''

# Add transcripts and matched filenames to the DataFrame
df['Transcript'], df['Matched Filename'] = zip(*df.apply(get_transcript_and_filename, axis=1))

# Save the updated DataFrame back to Excel
df.to_excel('updated_' + excel_file.split('/')[-1], index=False)

print("Process completed. Updated Excel file saved.")
# Out:
# Process completed. Updated Excel file saved.

# %%
import pandas as pd
import boto3
from botocore.exceptions import ClientError

# Set up AWS Translate client
translate = boto3.client('translate')

def split_text(text, max_bytes=9000, delimiter='|'):
    """Split text into chunks of maximum size in bytes, using the delimiter."""
    segments = text.split(delimiter)
    chunks = []
    current_chunk = ""
    
    for segment in segments:
        if len((current_chunk + delimiter + segment).encode('utf-8')) > max_bytes:
            if current_chunk:
                chunks.append(current_chunk + delimiter)
                current_chunk = segment
            else:
                # Handle case where a single segment is larger than max_bytes
                segment_bytes = segment.encode('utf-8')
                while len(segment_bytes) > max_bytes:
                    split_point = segment_bytes[:max_bytes].rfind(b' ')
                    if split_point == -1:
                        split_point = max_bytes
                    chunks.append(segment_bytes[:split_point].decode('utf-8'))
                    segment_bytes = segment_bytes[split_point:]
                current_chunk = segment_bytes.decode('utf-8')
        else:
            if current_chunk:
                current_chunk += delimiter + segment
            else:
                current_chunk = segment
    
    if current_chunk:
        chunks.append(current_chunk)
    
    return chunks

def translate_text(text, source_lang='hi', target_lang='en', delimiter='|'):
    """Translate text using AWS Translate, handling large texts with delimiter."""
    try:
        chunks = split_text(text, delimiter=delimiter)
        translated_chunks = []
        
        for chunk in chunks:
            response = translate.translate_text(
                Text=chunk,
                SourceLanguageCode=source_lang,
                TargetLanguageCode=target_lang
            )
            translated_chunks.append(response['TranslatedText'])
        
        return delimiter.join(translated_chunks)
    except ClientError as e:
        print(f"Error translating text: {e}")
        return None

# Load the Excel file
excel_file = 'updated_video_info.xlsx'  # Replace with your actual file name
df = pd.read_excel(excel_file)

# Add a new column for translations
df['Translation'] = ''

# Translate each transcript
for index, row in df.iterrows():
    if pd.notna(row['Transcript']):
        translation = translate_text(row['Transcript'])
        if translation:
            df.at[index, 'Translation'] = translation
            print(f"Successfully translated transcript for {row['Title']}")
        else:
            print(f"Failed to translate transcript for {row['Title']}")
    else:
        print(f"No transcript found for {row['Title']}")

# Save the updated DataFrame back to Excel
output_file = 'updated_' + excel_file
df.to_excel(output_file, index=False)

print(f"Processing completed. Updated Excel file saved as '{output_file}'")
# Out:
# Successfully translated transcript for PM Modi's speech at BJP HQ after NDA win in 2024 Lok Sabha Elections
# Successfully translated transcript for PM Modi addresses a public meeting in Hoshiarpur, Punjab
# Successfully translated transcript for PM Modi addresses a public meeting in Kendrapara, Odisha
# Successfully translated transcript for PM Modi addresses a public meeting in Balasore, Odisha
# Successfully translated transcript for PM Modi addresses a public meeting in Mayurbhanj, Odisha
# Successfully translated transcript for PM Modi addresses a public meeting in Mathurapur, West Bengal
# Successfully translated transcript for PM Modi addresses a public meeting in Jadavpur, West Bengal
# Successfully translated transcript for PM Modi addresses a public meeting in Barasat, West Bengal
# Successfully translated transcript for PM Modi addresses a public meeting in Dumka, Jharkhand
# Successfully translated transcript for PM Modi addresses a public meeting in Bansgaon, Uttar Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Ghosi, Uttar Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Mirzapur, Uttar Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Ghazipur, Uttar Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Buxar, Bihar
# Successfully translated transcript for PM Modi addresses a public meeting in Karakat, Bihar
# Successfully translated transcript for PM Modi addresses a public meeting in Pataliputra, Bihar
# Successfully translated transcript for PM Modi addresses a public meeting in Jalandhar, Punjab
# Successfully translated transcript for PM Modi addresses a public meeting in Gurdaspur, Punjab
# Successfully translated transcript for PM Modi addresses a public meeting in Mandi, Himachal Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Shimla, Himachal Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Patiala, Punjab
# Successfully translated transcript for PM Modi addresses a public meeting in Bhiwani-Mahendragarh, Haryana
# Successfully translated transcript for PM Modi addresses a public meeting in  Dwarka, West Delhi
# Successfully translated transcript for PM Modi addresses a public meeting in Shravasti, Uttar Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Basti, Uttar Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Prayagraj, Uttar Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Maharajganj, Bihar
# Successfully translated transcript for PM Modi addresses a public meeting in East Champaran, Bihar
# Successfully translated transcript for PM Modi addresses a public meeting in Jhargram, West Bengal
# Successfully translated transcript for PM Modi addresses a public meeting in Cuttack, Odisha
# Successfully translated transcript for PM Modi addresses a public meeting in Dhenkanal, Odisha
# Successfully translated transcript for LIVE: PM Modi's roadshow in Puri, Odisha today | Lok Sabha Election 2024
# Successfully translated transcript for PM Modi addresses a public meeting in Medinipur, West Bengal
# Successfully translated transcript for PM Modi addresses a public meeting in Bishnupur, West Bengal
# Successfully translated transcript for PM Modi addresses a public meeting in Purulia, West Bengal
# Successfully translated transcript for PM Modi addresses a public meeting in Jamshedpur, Jharkhand
# Successfully translated transcript for PM Modi addresses a public meeting in North East Delhi
# Successfully translated transcript for PM Modi addresses a public meeting in Sonipat, Haryana
# Successfully translated transcript for PM Modi addresses a public meeting in Ambala, Haryana
# Successfully translated transcript for PM Modi addresses a public meeting in Shivaji Park, Mumbai, Maharashtra
# Successfully translated transcript for PM Modi addresses a public meeting in Hamirpur, Uttar Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Fatehpur, Uttar Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Barabanki, Uttar Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Pratapgarh, Uttar Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Bhadohi, Uttar Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Jaunpur, Uttar Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Lalganj, Uttar Pradesh
# Successfully translated transcript for LIVE: PM Modi's roadshow in Mumbai North East, Maharashtra today | Lok Sabha Election 2024
# Successfully translated transcript for PM Modi addresses a public meeting in Kalyan, Maharashtra
# Successfully translated transcript for PM Modi addresses a public meeting in Dindori, Maharashtra
# Successfully translated transcript for PM Modi addresses a public meeting in Koderma, Jharkhand
# Successfully translated transcript for LIVE: PM Modi's roadshow in Varanasi, Uttar Pradesh today | Lok Sabha Election 2024
# Successfully translated transcript for PM Modi addresses a public meeting in Saran, Bihar
# Successfully translated transcript for PM Modi addresses a public meeting in Muzaffarpur, Bihar
# Successfully translated transcript for PM Modi addresses a public meeting in Hajipur, Bihar
# Successfully translated transcript for LIVE: PM Modi's roadshow in Patna, Bihar today | Lok Sabha Election 2024
# Successfully translated transcript for PM Modi addresses a public meeting in Howrah, West Bengal
# Successfully translated transcript for PM Modi addresses a public meeting in Arambagh, West Bengal
# Successfully translated transcript for PM Modi addresses a public meeting in Hooghly, West Bengal
# Successfully translated transcript for PM Modi addresses a public meeting in Barrackpore, West Bengal
# Successfully translated transcript for PM Modi addresses a public meeting in Chatra, Jharkhand
# Successfully translated transcript for PM Modi addresses a public meeting in Bargarh, Odisha
# Successfully translated transcript for PM Modi addresses a public meeting in Balangir, Odisha
# Successfully translated transcript for PM Modi addresses a public meeting in Kandhamal, Odisha
# Successfully translated transcript for LIVE: PM Modi's roadshow in Bhubaneswar, Odisha today | Lok Sabha Election 2024
# Successfully translated transcript for PM Modi addresses a public meeting in Hyderabad, Telangana
# Successfully translated transcript for PM Modi addresses a public meeting in Mahabubnagar, Telangana
# Successfully translated transcript for PM Modi addresses a public meeting in Nandurbar, Maharashtra
# Successfully translated transcript for LIVE: PM Modi's roadshow in Vijayawada, Andhra Pradesh today | Lok Sabha Election 2024
# Successfully translated transcript for PM Modi addresses a public meeting in Rajampet, Andhra Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Warangal, Telangana
# Successfully translated transcript for PM Modi addresses a public meeting in Karimnagar, Telangana
# Successfully translated transcript for PM Modi addresses a public meeting in  Ahmednagar, Maharashtra
# Successfully translated transcript for PM Modi addresses a public meeting in Dhar, Madhya Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Khargone, Madhya Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Anakapalle, Andhra Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Rajahmundry, Andhra Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Nabarangpur, Odisha
# Successfully translated transcript for PM Modi addresses a public meeting in Berhampur, Odisha
# Successfully translated transcript for PM Modi addresses a public meeting in Dhaurahra, Uttar Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Etawah, Uttar Pradesh
# Successfully translated transcript for LIVE: PM Modi's roadshow in Kanpur, Uttar Pradesh today | Lok Sabha Election 2024
# Successfully translated transcript for PM Modi addresses a public meeting in Darbhanga, Bihar
# Successfully translated transcript for PM Modi addresses a public meeting in  Lohardaga, Jharkhand
# Successfully translated transcript for PM Modi addresses a public meeting in Palamu, Jharkhand
# Successfully translated transcript for LIVE: Ranchi's rousing welcome for PM Modi as he holds a roadshow
# Successfully translated transcript for PM Modi addresses a public meeting in Singhbhum, Jharkhand
# Successfully translated transcript for PM Modi addresses a public meeting in Bolpur, West Bengal
# Successfully translated transcript for PM Modi addresses a public meeting in Krishnanagar, West Bengal
# Successfully translated transcript for PM Modi addresses a public meeting in Bardhaman, West Bengal
# Successfully translated transcript for PM Modi addresses a public meeting in Jamnagar, Gujarat
# Successfully translated transcript for PM Modi addresses a public meeting in Junagadh, Gujarat
# Successfully translated transcript for PM Modi addresses a public meeting in  Surendranagar, Gujarat
# Successfully translated transcript for PM Modi addresses a public meeting in Anand, Gujarat
# Successfully translated transcript for PM Modi addresses a public meeting in Sabarkantha, Gujarat
# Successfully translated transcript for PM Modi addresses a public meeting in Banaskantha, Gujarat
# Successfully translated transcript for PM Modi addresses a public meeting in Zaheerabad, Telangana
# Successfully translated transcript for PM Modi addresses a public meeting in Latur, Maharashtra
# Successfully translated transcript for PM Modi addresses a public meeting in Madha, Maharashtra
# Successfully translated transcript for PM Modi addresses a public meeting in Pune, Maharashtra
# Successfully translated transcript for PM Modi addresses a public meeting in Satara, Maharashtra
# Successfully translated transcript for PM Modi addresses a public meeting in Solapur, Maharashtra
# Successfully translated transcript for PM Modi addresses a public meeting in Bagalkote, Karnataka
# Successfully translated transcript for PM Modi addresses a public meeting in Ballari, Karnataka
# Successfully translated transcript for PM Modi addresses a public meeting in Davanagere, Karnataka
# Successfully translated transcript for PM Modi addresses a public meeting in Uttara Kannada, Karnataka
# Successfully translated transcript for PM Modi addresses a public meeting in Belagavi, Karnataka
# Successfully translated transcript for PM Modi addresses a public meeting in South Goa
# Successfully translated transcript for PM Modi addresses a public meeting in Kolhapur, Maharashtra
# Successfully translated transcript for LIVE: PM Modi's roadshow in Bareilly, Uttar Pradesh today | Lok Sabha Election 2024
# Successfully translated transcript for PM Modi addresses a public meeting in Munger, Bihar
# Successfully translated transcript for PM Modi addresses a public meeting in Araria, Bihar
# Successfully translated transcript for PM Modi addresses a public meeting in Malda Uttar, West Bengal
# Successfully translated transcript for PM Modi addresses a public meeting in Shahjahanpur, Uttar Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Aonla, Uttar Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Agra, Uttar Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Morena, Madhya Pradesh
# Successfully translated transcript for LIVE: PM Modi's roadshow in Bhopal, Madhya Pradesh today | Lok Sabha Election 2024
# Successfully translated transcript for PM Modi addresses a public meeting in Betul, Madhya Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Sagar, Madhya Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Surguja, Chhattisgarh
# Successfully translated transcript for PM Modi addresses a public meeting in Mahasamund, Chhattisgarh
# Successfully translated transcript for PM Modi addresses a public meeting in Janjgir-Champa, Chhattisgarh
# Successfully translated transcript for PM Modi addresses a public meeting in Tonk-Sawai Madhopur, Rajasthan
# Successfully translated transcript for PM Modi addresses a public meeting in Aligarh, Uttar Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Banswara, Rajasthan
# Successfully translated transcript for PM Modi addresses a public meeting in Jalore, Rajasthan
# Successfully translated transcript for PM Modi addresses a public meeting in Bengaluru, Karnataka
# Successfully translated transcript for PM Modi addresses a public meeting in Chikkaballapur, Karnataka
# Successfully translated transcript for PM Modi addresses a public meeting in Nanded, Maharashtra
# Successfully translated transcript for PM Modi addresses a public meeting in Wardha, Maharashtra
# Successfully translated transcript for PM Modi addresses a public meeting in Damoh, Madhya Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Amroha, Uttar Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Agartala, Tripura
# Successfully translated transcript for PM Modi addresses a public meeting in Nalbari, Assam
# Successfully translated transcript for LIVE | Guwahati's glorious welcome for PM Modi as he holds a grand roadshow
# Successfully translated transcript for PM Modi addresses a public meeting in Raiganj, West Bengal
# Successfully translated transcript for PM Modi addresses a public meeting in Balurghat, West Bengal
# Successfully translated transcript for PM Modi addresses a public meeting in Purnea, Bihar
# Successfully translated transcript for PM Modi addresses a public meeting in Gaya, Bihar
# Successfully translated transcript for PM Modi addresses a public meeting in Tirunelveli, Tamil Nadu
# Successfully translated transcript for PM Modi addresses a public meeting in Attingal, Kerala
# Successfully translated transcript for PM Modi addresses a public meeting in Alathur, Kerala
# Successfully translated transcript for LIVE: PM Modi's roadshow in Mangaluru, Karnataka today | Lok Sabha Election 2024
# Successfully translated transcript for PM Modi addresses a public meeting in Mysuru, Karnataka
# Successfully translated transcript for PM Modi addresses a public meeting in Hoshangabad, Madhya Pradesh
# Successfully translated transcript for PM Modi's speech during release of BJP's Sankalp Patra 2024
# Successfully translated transcript for Live: PM Modi's roadshow in Dausa, Rajasthan today | Lok Sabha Election 2024
# Successfully translated transcript for PM Modi addresses a public meeting in Barmer, Rajasthan
# Successfully translated transcript for PM Modi addresses a public meeting in Udhampur, Jammu and Kashmir
# Successfully translated transcript for PM Modi addresses a public meeting in Karauli, Rajasthan
# Successfully translated transcript for PM Modi addresses a public meeting in Rishikesh, Uttarakhand
# Successfully translated transcript for PM Modi addresses a public meeting in Ramtek, Maharashtra
# Successfully translated transcript for PM Modi addresses a public meeting in Mettupalayam, Tamil Nadu
# Successfully translated transcript for PM Modi addresses a public meeting in Vellore, Tamil Nadu
# Successfully translated transcript for LIVE: PM Modi's roadshow in Chennai today | Lok Sabha Election 2024
# Successfully translated transcript for PM Modi addresses a public meeting in Balaghat, Madhya Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Pilibhit, Uttar Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Chandrapur, Maharashtra
# Successfully translated transcript for PM Modi addresses a public meeting in Bastar, Chhattisgarh
# Successfully translated transcript for LIVE: PM Modi holds a roadshow in Jabalpur, Madhya Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Jalpaiguri, West Bengal
# Successfully translated transcript for PM Modi addresses a public meeting in Nawada, Bihar
# No transcript found for LIVE: PM Modi holds a dynamic roadshow in Ghaziabad, Uttar Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Ajmer, Rajasthan
# Successfully translated transcript for PM Modi addresses a public meeting in Saharanpur, Uttar Pradesh
# Successfully translated transcript for PM Modi addresses a public meeting in Churu, Rajasthan
# Successfully translated transcript for PM Modi addresses a public meeting in Coochbehar, West Bengal
# Successfully translated transcript for PM Modi addresses a public meeting in Jamui, Bihar
# Successfully translated transcript for PM Modi addresses a public meeting in Kotputli, Rajasthan
# Successfully translated transcript for PM Modi addresses a public meeting in Rudrapur, Uttarakhand
# Successfully translated transcript for PM Modi addresses a public meeting in Meerut, UP
# Successfully translated transcript for PM Modi addresses a public rally in Salem, Tamil Nadu
# Successfully translated transcript for LIVE: PM Modi's roadshow in Palakkad, Kerala | Lok Sabha Election 2024
# Successfully translated transcript for PM Modi's Coimbatore Roadshow Live | Lok Sabha Election 2024
# Successfully translated transcript for PM Modi addresses a public rally in Shivamogga, Karnataka
# Successfully translated transcript for PM Modi addresses a public rally in Jagtial, Telangana
# Successfully translated transcript for PM Modi addresses a public meeting in Kalaburagi, Karnataka
# Successfully translated transcript for PM Modi addresses a public meeting in Nagarkurnool, Telangana
# Successfully translated transcript for LIVE: PM Modi's marvellous road show in Malkajgiri, Hyderabad in Telangana
# Successfully translated transcript for PM Modi addresses a public meeting in Pathanamthitta, Kerala
# Successfully translated transcript for PM Modi addresses a public meeting in Kanyakumari, Tamil Nadu
# Processing completed. Updated Excel file saved as 'updated_updated_video_info.xlsx'
